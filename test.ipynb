# %%
import networkx as nx

# %%
G = nx.DiGraph()
G.add_edge(1,2, labels="5", flow='3')
G.add_edge(2, 3, labels="4", flow='3')
G.add_edge(3, 1, labels="1", flow='1')
G.add_edge(3, 4, labels="7", flow='2')
G.add_edge(2, 4, labels="10", flow='8')

# %%
nx.draw(G)

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
pos = nx.random_layout(G)
nx.draw(G, with_labels=True, pos=pos)
labels = nx.get_edge_attributes(G, 'labels')
nx.draw_networkx_edge_labels(G,pos=pos, edge_labels=labels)
plt.savefig("file.png", format="PNG")
plt.show()

# %%
G= nx.dodecahedral_graph()
edge_labels = nx.draw_networkx_edge_labels(G,pos=nx.spring_layout(G))

# %%
G=nx.Graph()
i=1
G.add_node(i,pos=(i,i))
G.add_node(2,pos=(2,2))
G.add_node(3,pos=(1,0))
G.add_edge(1,2,weight=0.5)
G.add_edge(1,3,weight=9.8)
pos=nx.get_node_attributes(G,'pos')
nx.draw(G,pos)
labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
# Out:
# {(1, 2): Text(1.5, 1.5, '0.5'), (1, 3): Text(1.0, 0.5, '9.8')}

# %%
G = nx.scale_free_graph(10)
nx.draw(G)
plt.show()
